# %%
import pandas as pd,\
        os

# %%
caminho_do_arquivo = os.path.join(os.path.expanduser("c:\\Data\\"), "Mega-Sena.xlsx")

# %%
# Use a função read_excel para ler o arquivo Excel e criar um DataFrame
df = pd.read_excel(caminho_do_arquivo, sheet_name="MEGA SENA")

# %%
df
# Out:
#       Concurso Data do Sorteio  Bola1  Bola2  Bola3  Bola4  Bola5  Bola6  \
# 0            1      11/03/1996      4      5     30     33     41     52
# 1            2      18/03/1996      9     37     39     41     43     49
# 2            3      25/03/1996     10     11     29     30     36     47
# 3            4      01/04/1996      1      5      6     27     42     59
# 4            5      08/04/1996      1      2      6     16     19     46
# ...        ...             ...    ...    ...    ...    ...    ...    ...
# 2664      2665      07/12/2023      3     14     21     22     37     39
# 2665      2666      09/12/2023      5     25     29     30     43     47
# 2666      2667      12/12/2023      1      4      8     21     46     51
# 2667      2668      14/12/2023      1     27     30     41     46     57
# 2668      2669      16/12/2023      4      7     16     35     46     54
#
#       Ganhadores 6 acertos Cidade / UF Rateio 6 acertos  Ganhadores 5 acertos  \
# ...

# %%
df.shape
# Out:
# (2669, 20)

# %%
df.drop(columns=['Concurso', 'Data do Sorteio', 'Ganhadores 6 acertos', 'Cidade / UF', \
       'Rateio 6 acertos', 'Ganhadores 5 acertos', 'Rateio 5 acertos', \
       'Ganhadores 4 acertos', 'Rateio 4 acertos', 'Acumulado 6 acertos',\
       'Arrecadação Total', 'Estimativa prêmio', \
       'Acumulado Sorteio Especial Mega da Virada', 'Observação'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (2669, 6)

# %%
df
# Out:
#       Bola1  Bola2  Bola3  Bola4  Bola5  Bola6
# 0         4      5     30     33     41     52
# 1         9     37     39     41     43     49
# 2        10     11     29     30     36     47
# 3         1      5      6     27     42     59
# 4         1      2      6     16     19     46
# ...     ...    ...    ...    ...    ...    ...
# 2664      3     14     21     22     37     39
# 2665      5     25     29     30     43     47
# 2666      1      4      8     21     46     51
# 2667      1     27     30     41     46     57
# 2668      4      7     16     35     46     54
#
# [2669 rows x 6 columns]

# %%
y = pd.get_dummies(df)
print(y.head())
# Out:
#    Bola1  Bola2  Bola3  Bola4  Bola5  Bola6
# 0      4      5     30     33     41     52
# 1      9     37     39     41     43     49
# 2     10     11     29     30     36     47
# 3      1      5      6     27     42     59
# 4      1      2      6     16     19     46

# %%
df.pivot()
